# %% [markdown]
# # ipython-sql showcase
# We load the `%sql` magic and connect to a MySQL database in the cloud.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql://bf152025fa6eaf:7fa53522@us-cdbr-iron-east-01.cleardb.net/heroku_7995446f6f15d7a?charset=utf8
# Out:
# u'Connected: bf152025fa6eaf@heroku_7995446f6f15d7a'

# %% [markdown]
# ## Let's see what is inside of our `test` table

# %%
# %sql select * from test order by id desc
# Out:
# 5 rows affected.
# [(3L, u'Nog eens'),
#  (2L, u'demo johan'),
#  (1L, u'thuis'),
#  (1L, u'thuis'),
#  (0L, u'insertion_test')]

# %% [markdown]
# ## we can also plot things

# %%
result = %sql select test_name, id from test
# Out:
# 5 rows affected.

# %%
# %matplotlib inline

# %%
result.bar()
# Out:
# <Container object of 5 artists>

# %%
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0xad4df8c>,
# ...
#   <matplotlib.text.Text at 0xad9610c>])

# %%
result.plot()
